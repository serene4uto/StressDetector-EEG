# %%
import mne
import os

# %%
DEAP_PATH = '/workspaces/Project_StressDetection/DEAP/data_original-001'
# raw_subject_dataset = []

# for file_name in os.listdir(DEAP_PATH):
#     if file_name.endswith('.bdf'):
#         print(file_name)
#         raw_subject_dataset.append(mne.io.read_raw_bdf(os.path.join(DEAP_PATH, file_name), preload=True))
        # raw = mne.io.read_raw_bdf(os.path.join(DEAP_PATH, file_name), preload=True)
        # raw.save(os.path.join(DEAP_PATH, file_name.replace('.bdf', '.fif')), overwrite=True)
        # del raw

# %%
raw_sub1 = mne.io.read_raw_bdf(os.path.join(DEAP_PATH, 's01.bdf'), preload=True)
# Out:
# Extracting EDF parameters from /workspaces/Project_StressDetection/DEAP/data_original-001/s01.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 1980927  =      0.000 ...  3868.998 secs...

# %%
type(raw_sub1)
# Out:
# mne.io.edf.edf.RawEDF

# %%
raw_sub1.info
# Out:
# <Info | 7 non-empty values
#  bads: []
#  ch_names: Fp1, AF3, F7, F3, FC1, FC5, T7, C3, CP1, CP5, P7, P3, Pz, PO3, ...
#  chs: 47 EEG, 1 Stimulus
#  custom_ref_applied: False
#  highpass: 0.0 Hz
#  lowpass: 104.0 Hz
#  meas_date: 2010-07-01 10:00:16 UTC
#  nchan: 48
#  projs: []
#  sfreq: 512.0 Hz
# >

# %%
fig = raw_sub1.plot(n_channels=32, )
fig.set_dpi(300)
fig.set_size_inches(20, 1)
# Out:
# <MNEBrowseFigure size 800x800 with 4 Axes>
